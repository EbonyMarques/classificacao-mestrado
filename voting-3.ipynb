# %%
import pandas as pd
from sklearn.metrics import classification_report
import shap
from aux_functions import load_and_preprocess_data_3
from aux_voting import voting_classification
import pickle

# %%
pd.set_option('display.max_columns', None)

# %%
data = load_and_preprocess_data_3().drop('id_discente',axis=1)
labels = {0: '1. Evasão até\n 2 anos',
          1: '2. Evasão entre\n 2 e 4 anos',
          2: '3. Evasão após\n 4 anos',
          3: '4. Formação', 
          }
# Out:
# 0    1518
# 1    1518
# 2    1518
# 3    1518
# Name: situacao_final_discente, dtype: int64
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.

# %%
voting_classifier, X_train, X_test, y_test, y_pred, y_prob = voting_classification(data, labels, '3')
# Out:
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.

# %%
with open('3/voting/voting_classifier.pickle', 'wb') as file:
    pickle.dump(voting_classifier, file)

# %%
print(classification_report(y_test, y_pred, digits=6, target_names=['1. Evasão até 2 anos', '2. Evasão entre 2 e 4 anos', '3. Evasão após 4 anos', '4. Formação']))
# Out:
#                             precision    recall  f1-score   support
#
#       1. Evasão até 2 anos   0.705653  0.746392  0.725451       485
# 2. Evasão entre 2 e 4 anos   0.546485  0.536748  0.541573       449
#      3. Evasão após 4 anos   0.674033  0.572770  0.619289       426
#                4. Formação   0.705534  0.772727  0.737603       462
#
#                   accuracy                       0.660812      1822
#                  macro avg   0.657926  0.657159  0.655979      1822
#               weighted avg   0.659006  0.660812  0.658397      1822

# %%
background_summary = shap.sample(X_train, 100)
explainer = shap.KernelExplainer(voting_classifier.predict_proba, background_summary, link="logit")
shap_values = explainer.shap_values(X_test.loc[0:4])
shap.summary_plot(shap_values, X_test.loc[0:4], max_display=15)
# Out:
# X does not have valid feature names, but SVC was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 0/5 [00:00<?, ?it/s]
# X does not have valid feature names, but SVC was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but SVC was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but SVC was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but SVC was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but SVC was fitted with feature names
# ...
